# %%
first_name = "shridevi"
print(first_name)
# Out:
# shridevi

# %%
a,b=2,3
print(a)
print(b)
# Out:
# 2
# 3

# %%
if 5>2:
    print("5 is big")
# Out:
# 5 is big

# %%
age=int(input("Enter num:"))
print(age)
# Out:
# Enter num: 2
# 2

# %%
name="Shridevi"
print(name)
# Out:
# Shridevi

# %%
type(name)
# Out:
# str

# %%
name=input("Enter your name:")
print(name)
# Out:
# Enter your name: 5
# 5

# %%
print("Div:",5/2)
print("floor div:",5//2)
print("Remainder(modulus):",5%2)
# Out:
# Div: 2.5
# floor div: 2
# Remainder(modulus): 1

# %%
print(10%10)
# Out:
# 0

# %%
a=5
b=2
if b>=a:
    print("Hi")
elif a<=b:
    print("Hello")
elif a==b:
    print("Good afternoon")
else:
    print("Bye!")
# Out:
# Bye!

# %%
x = "false"
print(type(x))
# Out:
# <class 'str'>

# %%
val = str(4)
print(val)
print(type(val))
# Out:
# 4
# <class 'str'>

# %%
num = int("4")
print(type(num))
# Out:
# <class 'int'>

# %%
ht = int(5.67)
print(ht)
# Out:
# 5

# %%
wt=float(5.6)
print(wt)
# Out:
# 5.6

# %%
Int = "12345"
for i in Int:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
ls = [2,3,4,5]
print("Add:",sum(ls))
# Out:
# Add: 14

# %%
len([2])
# Out:
# 1
