# %% [markdown]
# ADD TWO NUMBERS

# %%
a=5
b=5
sum=a+b
print(sum)
# Out:
# 10

# %% [markdown]
# (Imp) REVERSE A STRING

# %%
s="python"
print(s[::-1])
# Out:
# nohtyp

# %% [markdown]
# CHECK IF THE NUMBER IS PRIME

# %%
n=8
if n>1:
    print("prime")
else:
    print("not prime")
# Out:
# prime

# %% [markdown]
# CHECK IF THE STRING IS PALINDROME

# %%
s="mam"
s=s.lower()
if s==s[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Palindrome

# %% [markdown]
# FIND FACTORIAL OF NUMBER

# %%
import math
n=5
print(math.factorial(n))
# Out:
# 120

# %% [markdown]
# PRINT FIBONACCI SEQUENCE UP TO N TERMS

# %%
n=7;
a,b=0,1
for _ in range(n):
    print(a,end="")
    a,b=b,a+b
# Out:
# 0112358

# %% [markdown]
# FIND GCD OF TWO NUMBERS

# %%
import math
a,b=24,36
print(math.gcd(a,b))
# Out:
# 12

# %% [markdown]
# CHECK IF ARRAY AS DUPLICATES

# %%
arr=[1,2,3,4,5]
print("Duplicate found") 
if len(arr)!=len(set(arr)):
    print("No duplicates")
# Out:
# Duplicate found

# %% [markdown]
# FIND THE LONGEST SUBSTRING WITHOUT REPEATING CHARACTERS

# %%
s="abc"
longest=""
for i in range(len(s)):
    temp=""
    for j in s[i:]:
        if j not in temp:
            temp+=j;
            longest=max(longest,temp,key=len)
            print(longest,len(longest))
# Out:
# a 1
# ab 2
# abc 3
# abc 3
# abc 3
# abc 3

# %% [markdown]
# FIND SUBARRAY OF GIVEN SUM(NON NEGATIVE INTEGERS)

# %%
arr=[1,2,3,7,5];target=5
for i in range(len(arr)):
    s=0
    for j in range(i,len(arr)):
        s+=arr[j]
        if s==target: print(arr[i:j+1])
# Out:
# [2, 3]
# [5]

# %% [markdown]
# FIND 2 STRINGS ARE ANAGRAMS

# %%
a,b="listen","silent"
print("Anagram" if sorted(a)==sorted(b) else "Not Anagram")
# Out:
# Anagram

# %% [markdown]
# (Imp) FIND 1st NON REPEATING CHARACTER IN STRING

# %%
s="wow"
for i in s:
    if s.count(i)==1:
        print(i);
        break
# Out:
# o

# %% [markdown]
# FIND THE HCF OF 2 NUMBER WITHOUT USING RECURSION

# %%
a,b=24,36
while b:
    a,b=b,a%b
print("HCF=",a)
# Out:
# HCF= 12

# %% [markdown]
# CALCULATE SUM OF DIGITS OF A NUMBER

# %%
n=123
s=0
while n>0:
    s+=n%10
    n//=10
print("Sum=",s)
# Out:
# Sum= 6

# %% [markdown]
# CONVERT DECIMAL TO BINARY NUMBER

# %%
n=10
b=bin(n)[2:]
print("Binary=",b)
# Out:
# Binary= 1010

# %% [markdown]
# COUNT THE NUMBER OF VOWELS IN A STRING

# %%
s="education"
c=len([1 for ch in s if ch in "aeiouAEIOU"])
print("Vowels=",c)
# Out:
# Vowels= 5

# %% [markdown]
# A SIMPLE METHOD TO SORT AN ARRAY OF INTEGERS IN ASCENDING AND DECENDING ORDER

# %%
arr = [1, 2, 3, 4]
print("Ascending =", sorted(arr))
print("Descending =", sorted(arr, reverse=True))
# Out:
# Ascending = [1, 2, 3, 4]
# Descending = [4, 3, 2, 1]

# %% [markdown]
# HOW TO REVERSE A LINKED LIST

# %%
list=[1,2,3,4]
list.reverse()
print("Reverse=",list)
# Out:
# Reverse= [4, 3, 2, 1]

# %% [markdown]
# WRITE A FUNCTION TO CLONE A LINKED LIST

# %%
list=[5,6,7,8]
clone=list.copy()
print("clone list=",clone)
# Out:
# clone list= [5, 6, 7, 8]

# %% [markdown]
# HOW TO DELETE A NODE IN A LINKED LIST

# %%
list=[2,4,6,8]
list.remove(4)
print("After deletion=",list)
# Out:
# After deletion= [2, 6, 8]

# %%
arr,k=[1,2,3,4,5],5
res=sorted(arr,reverse=True)[k-1]
print("kth largest=",res)
# Out:
# kth largest= 1

# %%
tree = [1,2,3,4,5,6,7]
balanced = abs(len(tree[:len(tree)//2]) - len(tree[len(tree)//2:])) <= 1
print("Balanced" if balanced else "Not balanced")
# Out:
# Balanced

# %% [markdown]
# SQL

# %%
import sqlite3
con=sqlite3.connect(":memory:")
con.execute("CREATE TABLE Employee(emp_id INT,name TEXT,salary INT)")
con.execute("INSERT INTO Employee VALUES(1,'Ravi',30000),(2,'Neha',40000),(3,'Amit',35000)")

# %%
import pandas as pd
pd.read_sql("SELECT*FROM Employee",con)
# Out:
#    emp_id  name  salary
# 0       1  Ravi   30000
# 1       2  Neha   40000
# 2       3  Amit   35000

# %%
print(list(con.execute("SELECT MAX(salary)FROM Employee WHERE salary < (SELECT MAX(salary) FROM Employee)")));
# Out:
# [(35000,)]

# %%
print(list(con.execute("SELECT name, COUNT(*) FROM Student GROUP BY name HAVING COUNT(*) > 1)))
# Out:
#   Cell In[18], line 1
#     print(list(con.execute("SELECT name, COUNT(*) FROM Student GROUP BY name HAVING COUNT(*) > 1)))
#                            ^
# SyntaxError: unterminated string literal (detected at line 1)
